# %%
import networkx as nx
import matplotlib.pyplot as mpl
import plotly.plotly as plt
import plotly.graph_objs as go
import math
import json
import pprint

# %matplotlib notebook

# %%
retweeter_to_owner_relation = {}

# %%
with open("data.json") as tweets:
    for tweet in tweets:
        tweet_json = json.loads(tweet)
        if("retweeted_status" in tweet_json):
            if(tweet_json["user"]["screen_name"] in retweeter_to_owner_relation):
                retweeter_to_owner_relation[tweet_json["user"]["screen_name"]] += tweet_json["retweeted_status"]["user"]["screen_name"]
            else:
                retweeter_to_owner_relation[tweet_json["user"]["screen_name"]] = [tweet_json["retweeted_status"]["user"]["screen_name"]]

# %%
print(retweeter_to_owner_relation)
G = nx.DiGraph()
for retweeter in retweeter_to_owner_relation.keys():
    G.add_edge(retweeter,retweeter_to_owner_relation[retweeter])
# Out:
# {'Ayn_lh': '_nanaaaass_nanaaaass_nanaaaass', 'zelenkovaolya96': 'gigtricksglobalgigtricksglobalgigtricksglobal', 'eToroMarketeers': 'lovebooalwayslovebooalwayslovebooalways', 'yamaken37': 'ftnextftnextftnext', 'Orlandaxgsf': 'DeepAeroDronesDeepAeroDronesDeepAeroDrones', 'mgmfx': 'dropp_tvdropp_tvdropp_tv', 'IgorCarron': 'fcholletfcholletfchollet', 'airdrop_free': 'OKEx_OKEx_OKEx_', 'kryuchkova11': 'IrinaP29305059IrinaP29305059IrinaP29305059', 'veroniccka111': 'ShareRingCoShareRingCoShareRingCo', 'AlexRain10': 'CTXCBlockchainCTXCBlockchainCTXCBlockchain'}

# %%
mpl.figure()
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="640">
